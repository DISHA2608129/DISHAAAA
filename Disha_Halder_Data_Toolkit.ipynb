# %% [markdown]
# <a href="https://colab.research.google.com/github/DISHA2608129/DISHAAAA/blob/main/Disha_Halder_Data_Toolkit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Demonstrate three different methods for creating identical 2D arrays in NumPy. Provide the code for each
# method and the final output after each method.

# %%
import numpy as np

# Method 1: Creating array from a nested list
array1 = np.array([[1, 2, 3], [4, 5, 6]])
print("Method 1 Output:\n", array1)
# Out:
# Method 1 Output:
#  [[1 2 3]
#  [4 5 6]]

# %%
# Method 2: Using np.full (manually building the array)
array2 = np.full((2, 3), 0)  # First create with zeros
array2[0] = [1, 2, 3]
array2[1] = [4, 5, 6]
print("Method 2 Output:\n", array2)
# Out:
# Method 2 Output:
#  [[1 2 3]
#  [4 5 6]]

# %%
# Method 3: Using np.reshape
array3 = np.array([1, 2, 3, 4, 5, 6]).reshape(2, 3)
print("Method 3 Output:\n", array3)
# Out:
# Method 3 Output:
#  [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# 2. Using the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and
# Reshape that 1D array into a 2D array.

# %%
import numpy as np

# Generate 100 evenly spaced numbers between 1 and 10
array_1d = np.linspace(1, 10, 100)

# Reshape the 1D array into a 2D array, for example: 10 rows x 10 columns
array_2d = array_1d.reshape(10, 10)

# Print the 2D array
print("2D Array:\n", array_2d)
# Out:
# 2D Array:
#  [[ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#    1.54545455  1.63636364  1.72727273  1.81818182]
#  [ 1.90909091  2.          2.09090909  2.18181818  2.27272727  2.36363636
#    2.45454545  2.54545455  2.63636364  2.72727273]
#  [ 2.81818182  2.90909091  3.          3.09090909  3.18181818  3.27272727
#    3.36363636  3.45454545  3.54545455  3.63636364]
#  [ 3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#    4.27272727  4.36363636  4.45454545  4.54545455]
#  [ 4.63636364  4.72727273  4.81818182  4.90909091  5.          5.09090909
#    5.18181818  5.27272727  5.36363636  5.45454545]
#  [ 5.54545455  5.63636364  5.72727273  5.81818182  5.90909091  6.
#    6.09090909  6.18181818  6.27272727  6.36363636]
#  [ 6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#    7.          7.09090909  7.18181818  7.27272727]
#  [ 7.36363636  7.45454545  7.54545455  7.63636364  7.72727273  7.81818182
# ...

# %% [markdown]
# 3. Explain the following termsg
# M The difference in np.array, np.asarray and np.asanyarrayX
# M The difference between Deep copy and shallow copy

# %% [markdown]
# Difference Between np.array, np.asarray, and np.asanyarray
# np.array()
#
# Always creates a new NumPy array from any input (like lists or tuples).
#
# Even if the input is already an array, it will still create a new one unless copy=False.
#
# np.asarray()
#
# Converts the input into a NumPy array only if it’s not already one.
#
# More efficient when working with existing arrays, since it avoids unnecessary copies.
#
# np.asanyarray()
#
# Similar to np.asarray() but it also preserves NumPy subclasses, such as np.matrix or masked arrays.
#
# Useful when you want to keep special behaviors associated with subclasses.
#
# Key Point:
# Use asarray for efficiency and asanyarray when working with custom array types.
#
# Difference Between Deep Copy and Shallow Copy
# Shallow Copy
#
# Only copies the reference to the original object, not the data itself.
#
# If you change the original array, the shallow copy reflects those changes.
#
# Deep Copy
#
# Makes a completely independent copy of the object and its data.
#
# Changes to one do not affect the other.
#
# Key Point:
# Use .copy() in NumPy or copy.deepcopy() in general Python when you want a deep, independent copy of the data.

# %% [markdown]
# 4. Generate a 3x3 array with random floating-point numbers between 5 and 20. Then, round each number in
# the array to 2 decimal places.

# %%
import numpy as np

# Generate 3x3 array with random floats between 5 and 20
random_array = np.random.uniform(5, 20, size=(3, 3))

# Round each number to 2 decimal places
rounded_array = np.round(random_array, 2)

print("Original Random Array:\n", random_array)
print("\nRounded Array (2 decimal places):\n", rounded_array)
# Out:
# Original Random Array:
#  [[16.70026134 16.86472059 13.30067181]
#  [10.20422867  5.22807387 12.66784396]
#  [11.00132397 12.17486661 16.41457731]]
#
# Rounded Array (2 decimal places):
#  [[16.7  16.86 13.3 ]
#  [10.2   5.23 12.67]
#  [11.   12.17 16.41]]

# %% [markdown]
# 5. Create a NumPy array with random integers between 1 and 10 of shape (5, 6). After creating the array
# perform the following operations:
#
#  a)Extract all even integers from array.
#
#  b)Extract all odd integers from arrayX

# %%
import numpy as np

# Create a (5, 6) array of random integers between 1 and 10 (inclusive)
array = np.random.randint(1, 11, size=(5, 6))

# Extract even integers
even_integers = array[array % 2 == 0]

# Extract odd integers
odd_integers = array[array % 2 != 0]

# Display the results
print("Original Array:\n", array)
print("\nEven Integers:\n", even_integers)
print("\nOdd Integers:\n", odd_integers)
# Out:
# Original Array:
#  [[ 9  7 10  3  8  6]
#  [ 7  4  4 10  9  1]
#  [ 6  4 10  1  4  1]
#  [ 3  9  2  6  9  1]
#  [ 1  5  7  4  6  9]]
#
# Even Integers:
#  [10  8  6  4  4 10  6  4 10  4  2  6  4  6]
#
# Odd Integers:
#  [9 7 3 7 9 1 1 1 3 9 9 1 1 5 7 9]

# %% [markdown]
# 6.  Create a 3D NumPy array of shape (3, 3, 3) containing random integers between 1 and 10. Perform the
# following operations:
#
#  a) Find the indices of the maximum values along each depth level (third axis).
#
#  b) Perform element-wise multiplication of between both arrayX

# %%
import numpy as np

# Create a 3D array of shape (3, 3, 3) with random integers between 1 and 10
array_3d = np.random.randint(1, 11, size=(3, 3, 3))

# a) Find the indices of the maximum values along each depth level (axis=2)
max_indices = np.argmax(array_3d, axis=2)

# b) Perform element-wise multiplication with another (3, 3, 3) random integer array
another_array = np.random.randint(1, 11, size=(3, 3, 3))
elementwise_product = array_3d * another_array

# Display results
print("Original 3D Array:\n", array_3d)
print("\nAnother 3D Array:\n", another_array)
print("\nIndices of Maximum Values Along Depth Level (Axis=2):\n", max_indices)
print("\nElement-wise Multiplication Result:\n", elementwise_product)
# Out:
# Original 3D Array:
#  [[[ 3 10  1]
#   [ 6  9  2]
#   [ 8  1  1]]
#
#  [[ 1  4  2]
#   [ 9  6  2]
#   [ 7 10  4]]
#
#  [[ 2  5  3]
#   [ 2  1  5]
#   [ 8  1 10]]]
#
# Another 3D Array:
#  [[[ 7  7 10]
#   [ 6 10  1]
#   [ 4  3  2]]
#
#  [[ 4  2  4]
#   [ 5  8  6]
#   [ 6  7  2]]
#
#  [[ 4 10  7]
#   [ 9  8  3]
#   [ 7  9  3]]]
#
# Indices of Maximum Values Along Depth Level (Axis=2):
#  [[1 1 0]
#  [1 0 1]
#  [1 2 2]]
#
# Element-wise Multiplication Result:
#  [[[21 70 10]
#   [36 90  2]
#   [32  3  2]]
#
#  [[ 4  8  8]
#   [45 48 12]
#   [42 70  8]]
#
#  [[ 8 50 21]
#   [18  8 15]
#   [56  9 30]]]

# %% [markdown]
# 7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and
# convert it to a numeric data type. Also display the table attributes and data types of each column.

# %%
import pandas as pd

# Sample dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Phone': ['+44-7911-123456', '(020) 7946 0958', '07911 234567'],
    'Email': ['alice@example.com', 'bob@example.com', 'charlie@example.com']
}

# Create DataFrame
df = pd.DataFrame(data)

# Clean 'Phone' column to keep only numeric characters
df['Phone'] = df['Phone'].str.replace(r'\D', '', regex=True)

# Convert to numeric type (optional: you can also keep it as string if leading zeros are important)
df['Phone'] = pd.to_numeric(df['Phone'])

# Display cleaned DataFrame
print("Cleaned DataFrame:\n", df)

# Display DataFrame info (attributes and data types)
print("\nData Types and Attributes:")
print(df.info())
# Out:
# Cleaned DataFrame:
#        Name         Phone                Email
# 0    Alice  447911123456    alice@example.com
# 1      Bob    2079460958      bob@example.com
# 2  Charlie    7911234567  charlie@example.com
#
# Data Types and Attributes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Phone   3 non-null      int64
#  2   Email   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %% [markdown]
# 13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the
# following tasks using Matplotlib and NumPy:
#
# a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
#
# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
#
# c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
#
# d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
#
# e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.
#
# f) Display a legend for the scatter plot, the horizontal line, and the vertical line

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', marker='o', label='Random Points')

# Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# Label axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add a title
plt.title('Advanced Scatter Plot of Random Values')

# Display the legend
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 14. Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and
# Perform the following tasks using Matplotlib:
# K§g Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following
# tasks using Matplotlib:
# KÃg Set the title of the plot as 'Histogram with PDF Overlay'.
# Kçg Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the
# origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.
# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and
# right y-axis for 'Humidity').
#
# b) Label the x-axis as 'Date'.
#
# c) Set the title of the plot as 'Temperature and Humidity Over Time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# 1. Time-Series Dataset Creation
np.random.seed(42)
dates = pd.date_range(start='2024-01-01', periods=100)
temperature = np.random.normal(loc=20, scale=5, size=100)
humidity = np.random.normal(loc=60, scale=10, size=100)
df = pd.DataFrame({'Date': dates, 'Temperature': temperature, 'Humidity': humidity})

# a) Dual-axis Plot for Temperature and Humidity
fig, ax1 = plt.subplots(figsize=(10, 5))

ax2 = ax1.twinx()
ax1.plot(df['Date'], df['Temperature'], 'r-', label='Temperature')
ax2.plot(df['Date'], df['Humidity'], 'b-', label='Humidity')

ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='r')
ax2.set_ylabel('Humidity (%)', color='b')
plt.title('Temperature and Humidity Over Time')
fig.tight_layout()
plt.show()

# 2. Histogram with PDF Overlay
data = np.random.normal(0, 1, 1000)
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=30, kde=False, color='skyblue', stat='density', label='Histogram')

# PDF Overlay
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, 0, 1)
plt.plot(x, pdf, 'r-', label='PDF')
plt.title('Histogram with PDF Overlay')
plt.legend()
plt.grid(True)
plt.show()

# 3. Seaborn Quadrant-wise Scatter Plot
x = np.random.randn(300)
y = np.random.randn(300)
quadrant = np.where((x >= 0) & (y >= 0), 'Q1',
            np.where((x < 0) & (y >= 0), 'Q2',
            np.where((x < 0) & (y < 0), 'Q3', 'Q4')))
df_scatter = pd.DataFrame({'x': x, 'y': y, 'Quadrant': quadrant})

plt.figure(figsize=(7, 7))
sns.scatterplot(data=df_scatter, x='x', y='y', hue='Quadrant', palette='Set1')
plt.axhline(0, color='gray', linestyle='--')
plt.axvline(0, color='gray', linestyle='--')
plt.title('Quadrant-wise Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 15.  Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following
# tasks using Matplotlib:
#
# a) Plot a histogram of the data with 30 bins.
#
# b) Overlay a line plot representing the normal distribution's probability density function (PDF).
#
# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.
#
# d) Set the title of the plot as 'Histogram with PDF Overlay

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# 1. Create a NumPy array with 1000 samples from a normal distribution
data = np.random.normal(0, 1, 1000)

# a) Plot a histogram of the data with 30 bins
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=30, kde=False, color='skyblue', stat='density', label='Histogram')

# b) Overlay a line plot representing the normal distribution's probability density function (PDF)
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, 0, 1)
plt.plot(x, pdf, 'r-', label='PDF')

# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# d) Set the title of the plot as 'Histogram with PDF Overlay'
plt.title('Histogram with PDF Overlay')
plt.legend()
plt.grid(True)
plt.show()

# 2. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants)
x = np.random.randn(300)
y = np.random.randn(300)

# Determine the quadrant based on x and y values
quadrant = np.where((x >= 0) & (y >= 0), 'Q1',
            np.where((x < 0) & (y >= 0), 'Q2',
            np.where((x < 0) & (y < 0), 'Q3', 'Q4')))
df_scatter = pd.DataFrame({'x': x, 'y': y, 'Quadrant': quadrant})

plt.figure(figsize=(7, 7))
sns.scatterplot(data=df_scatter, x='x', y='y', hue='Quadrant', palette='Set1')

# Add horizontal and vertical lines to indicate the quadrants
plt.axhline(0, color='gray', linestyle='--')
plt.axvline(0, color='gray', linestyle='--')

# Label the axes and set the title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')

# Add a legend
plt.legend(title='Quadrants')
plt.grid(True)
plt.show()

# 3. Time-Series Plot (Temperature and Humidity)
np.random.seed(42)
dates = pd.date_range(start='2024-01-01', periods=100)
temperature = np.random.normal(loc=20, scale=5, size=100)
humidity = np.random.normal(loc=60, scale=10, size=100)
df = pd.DataFrame({'Date': dates, 'Temperature': temperature, 'Humidity': humidity})

# a) Dual-axis plot for Temperature and Humidity
fig, ax1 = plt.subplots(figsize=(10, 5))

ax2 = ax1.twinx()
ax1.plot(df['Date'], df['Temperature'], 'r-', label='Temperature')
ax2.plot(df['Date'], df['Humidity'], 'b-', label='Humidity')

# b) Label the x-axis as 'Date'
ax1.set_xlabel('Date')

# c) Set the title of the plot as 'Temperature and Humidity Over Time'
ax1.set_ylabel('Temperature (°C)', color='r')
ax2.set_ylabel('Humidity (%)', color='b')
plt.title('Temperature and Humidity Over Time')

fig.tight_layout()
plt.show()

# %% [markdown]
# 16.  Set the title of the plot as 'Histogram with PDF Overlay'.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate 1000 random samples from a normal distribution
data = np.random.normal(0, 1, 1000)

# Plot a histogram of the data with 30 bins
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, density=True, color='skyblue', alpha=0.6, label='Histogram')

# Overlay a line plot representing the normal distribution's probability density function (PDF)
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, 0, 1)
plt.plot(x, pdf, 'r-', label='PDF')

# Label the x-axis and y-axis
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# Set the title of the plot as 'Histogram with PDF Overlay'
plt.title('Histogram with PDF Overlay')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# 17. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the
# origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Generate two random arrays of 100 points each
x = np.random.randn(100)
y = np.random.randn(100)

# Create a DataFrame with the x and y arrays
data = pd.DataFrame({'x': x, 'y': y})

# Create a new column 'quadrant' based on the position of each point relative to the origin
data['quadrant'] = np.where((data['x'] >= 0) & (data['y'] >= 0), 'Quadrant 1',
                            np.where((data['x'] < 0) & (data['y'] >= 0), 'Quadrant 2',
                                     np.where((data['x'] < 0) & (data['y'] < 0), 'Quadrant 3', 'Quadrant 4')))

# Create the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='x', y='y', data=data, hue='quadrant', palette='Set1', s=100)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')

# Display the legend
plt.legend(title='Quadrants')

# Show the plot
plt.show()

# %% [markdown]
# 18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine
# Wave Function

# %%
from bokeh.plotting import figure, show
import numpy as np

# Generate data for the sine wave
x = np.linspace(0, 4 * np.pi, 100)  # 100 points from 0 to 4*pi
y = np.sin(x)  # Sine of each x value

# Create a Bokeh plot
p = figure(title="Sine Wave Function", x_axis_label='X', y_axis_label='Y')

# Plot the sine wave as a line
p.line(x, y, legend_label="sin(x)", line_width=2, color="blue")

# Add grid lines
p.grid.visible = True

# Show the plot
show(p)

# %% [markdown]
# 19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their
# values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical
# Bar Chart

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.models import ColumnDataSource, HoverTool
import numpy as np
import pandas as pd

# Generate random categorical data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 20, size=5)  # Random values between 1 and 20

# Create a DataFrame for better handling of the data
data = pd.DataFrame({'Category': categories, 'Value': values})

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(data)

# Create a Bokeh figure
p = figure(x_range=categories, title="Random Categorical Bar Chart",
           toolbar_location=None, tools="")

# Create the bar chart
p.vbar(x='Category', top='Value', width=0.9, source=source, legend_field="Category",
       line_color="white", color="skyblue", fill_color="skyblue")

# Add hover tool to display the exact value
hover = HoverTool()
hover.tooltips = [("Category", "@Category"), ("Value", "@Value")]
p.add_tools(hover)

# Set axis labels
p.xaxis.axis_label = "Category"
p.yaxis.axis_label = "Value"

# Set properties for the plot
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

# Show the plot
output_file("bar_chart.html")
show(p)

# %% [markdown]
# 20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as
# 'Simple Line Plot'8

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data
x = np.linspace(0, 10, 100)  # 100 equally spaced points between 0 and 10
y = np.random.rand(100)  # Random y-values between 0 and 1

# Create the figure with a line plot
fig = go.Figure()

# Add a line plot to the figure
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

# Update the layout with title and axis labels
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis',
    template='plotly_dark'  # Optional: To set the background to dark
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set
# the title as 'Interactive Pie Chart'.

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data for the pie chart
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(1, 20, size=5)  # Random values for each category

# Create a pie chart figure
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='label+percent', hoverinfo='label+value+percent')])

# Update layout with title
fig.update_layout(
    title='Interactive Pie Chart'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
